# %% [markdown]
# <a href="https://colab.research.google.com/github/mnoofi/my-colab-projects/blob/main/task_matrix_2d.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
matrix=[["X" if row == column
  else "Even" if (row+column)%2==0
  else"Odd"
  for column in range(1,6)]for row in range (1,6)]
for row in matrix:
  print(row)
# Out:
# ['X', 'Odd', 'Even', 'Odd', 'Even']
# ['Odd', 'X', 'Odd', 'Even', 'Odd']
# ['Even', 'Odd', 'X', 'Odd', 'Even']
# ['Odd', 'Even', 'Odd', 'X', 'Odd']
# ['Even', 'Odd', 'Even', 'Odd', 'X']
